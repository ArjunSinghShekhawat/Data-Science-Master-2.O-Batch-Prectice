# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)
#
#
#
# Boxplot - It is used for outliers dedected.It is represent mininum number , 25% data , 50% data, 75% data and maximum data point,It is also called 5 number summary.

# %%
box1 = np.random.normal(100, 10, 200)
plt.boxplot(box1)
plt.show()

# %%
box2 = np.random.normal(90, 20, 200)
plt.boxplot(box2,notch=False)
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])
#
# The bar plot is used for categorical data and its preferenc represent.When x-axis is categorical and y-axis represent this categorical data importance then used bar plot.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
#
#
# Sub plot is used to represent multiple plot in the single figure.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])  
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])  
y3 = np.array([10, 20, 30, 40, 50, 60]) 
x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.xlabel('x-axis')
plt.ylabel('y-label')
plt.title('Subplot')

plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.xlabel('x-axis')
plt.ylabel('y-label')
plt.title('Subplot')

plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.xlabel('x-axis')
plt.ylabel('y-label')
plt.title('Subplot')

plt.subplot(2,2,4)
plt.scatter(x4,y4)
plt.xlabel('x-axis')
plt.ylabel('y-label')
plt.title('Subplot')
# Out:
# Text(0.5, 1.0, 'Subplot')

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.
#
# Scatter plot is used to represent the relationship between two and more than two variable.

# %%
x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-aixs')
# Out:
# Text(0, 0.5, 'y-aixs')

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib -: Matplotlib is a library that is used for visualize the data in graphical form.
# It is used for better understanding of the row data by using graphical representation.
#
# There are multiple plot used in this library.
#
# 1.pie plot
#
# 2.bar plot
#
# 3.hist plot
#
# 4.scatter plot
#
# 5.line plot
#
# 6.box plot
