# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
import numpy as np

# %%
minimum,Q1,mean,Q3,maximum = np.quantile(df['age'],[0.0,0.25,0.50,0.75,1.0])

# %%
minimum
# Out:
# nan

# %%
maximum
# Out:
# nan

# %%
df[df['age'].isnull()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
import matplotlib.pyplot as plt
sns.displot(df['age'],kind='kde')
# Out:
# c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['age'].fillna(df['age'].median(),inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df['age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
sns.boxenplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
minimum,Q1,mean,Q3,maximum = np.quantile(df['age'],[0,0.25,0.50,0.75,1.0])

# %%
iqr = Q3-Q1

# %%
lower_fence = Q1-1.5*(iqr)

# %%
higher_fence = Q3+1.5*(iqr)

# %%
lower_fence
# Out:
# 2.5

# %%
higher_fence
# Out:
# 54.5

# %%
outliers = []

for i in df['age']:
    if i<lower_fence or i>higher_fence:
        df['age'].drop(i,inplace=True)
    else:
        print('Not Outlier present :')
# Out:
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# Not Outlier present :
# ...

# %%
outliers
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
for i in df['age']:
    print(i)
# Out:
# 22.0
# 38.0
# 26.0
# 35.0
# 35.0
# nan
# 54.0
# 2.0
# 27.0
# 14.0
# 4.0
# 58.0
# 20.0
# 39.0
# 14.0
# 55.0
# 2.0
# nan
# 31.0
# nan
# 35.0
# 34.0
# 15.0
# 28.0
# 8.0
# 38.0
# nan
# 19.0
# nan
# nan
# 40.0
# nan
# nan
# 66.0
# 28.0
# 42.0
# nan
# 21.0
# 18.0
# 14.0
# 40.0
# 27.0
# nan
# 3.0
# 19.0
# nan
# nan
# nan
# nan
# 18.0
# 7.0
# 21.0
# 49.0
# 29.0
# 65.0
# nan
# 21.0
# 28.5
# 5.0
# 11.0
# 22.0
# 38.0
# 45.0
# 4.0
# nan
# nan
# 29.0
# 19.0
# 17.0
# 26.0
# 32.0
# 16.0
# 21.0
# 26.0
# 32.0
# 25.0
# nan
# nan
# 0.83
# 30.0
# 22.0
# 29.0
# nan
# 28.0
# 17.0
# 33.0
# 16.0
# nan
# 23.0
# 24.0
# 29.0
# 20.0
# 46.0
# 26.0
# 59.0
# nan
# 71.0
# 23.0
# 34.0
# 34.0
# 28.0
# nan
# 21.0
# 33.0
# 37.0
# 28.0
# 21.0
# nan
# 38.0
# nan
# 47.0
# 14.5
# 22.0
# 20.0
# 17.0
# 21.0
# 70.5
# 29.0
# 24.0
# 2.0
# 21.0
# nan
# 32.5
# 32.5
# 54.0
# 12.0
# nan
# 24.0
# nan
# 45.0
# 33.0
# 20.0
# 47.0
# 29.0
# 25.0
# 23.0
# 19.0
# 37.0
# 16.0
# 24.0
# nan
# 22.0
# 24.0
# 19.0
# 18.0
# 19.0
# 27.0
# 9.0
# ...

# %%
df['age'].fillna(df['age'].median(),inplace=True)

# %%
df[df['age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
sns.boxenplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
minimum,Q1,mean,Q3,maximum = np.quantile(df['age'],[0,0.25,0.50,0.75,1.0])

# %%
iqr = Q3-Q1

# %%
lower_fence = Q1-1.5*(iqr)

# %%
higher_fence = Q3+1.5*(iqr)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[df['age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
outliers = []
for age in df['age']:
    if age<lower_fence or age>higher_fence:
        outliers.append(age)
        
    else:
        print('Outlier nhi hai ')
# Out:
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# Outlier nhi hai
# ...

# %%
df[df['age']==0.83]
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked   class  \
# 78          1       2  male  0.83      0      2  29.00        S  Second
# 831         1       2  male  0.83      1      1  18.75        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 78   child       False  NaN  Southampton   yes  False
# 831  child       False  NaN  Southampton   yes  False

# %%
outliers
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
len(outliers)
# Out:
# 66
