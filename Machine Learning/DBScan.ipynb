# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples=1000,noise=0.05)

# %%
x
# Out:
# array([[ 0.4904391 , -0.46002475],
#        [-1.03280987,  0.05426729],
#        [ 0.04403735,  0.16432221],
#        ...,
#        [ 1.56920229, -0.25859827],
#        [ 0.47242883, -0.45119141],
#        [ 0.23021264,  1.04196197]])

# %%
plt.scatter(x[:,0],x[:,1])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x)

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan  = DBSCAN(eps=0.50)
dbscan.fit(x_train)
# Out:
# DBSCAN()

# %%
plt.scatter(x_train[:,0],x_train[:,1],c=dbscan.labels_)

# %%
from sklearn.metrics import silhouette_score

# %%
print(silhouette_score(x_train,dbscan.labels_))
# Out:
# 0.39201926182527225
