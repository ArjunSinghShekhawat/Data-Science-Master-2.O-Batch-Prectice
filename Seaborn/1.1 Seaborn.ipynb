# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x = df['petal_length'],y = df['sepal_length'])
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.scatterplot(x = df['petal_width'],y = df['sepal_width'])
# Out:
# <Axes: xlabel='petal_width', ylabel='sepal_width'>

# %%
sns.histplot(df['sepal_length'],color='red')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
df1 = sns.load_dataset('tips')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=df1['total_bill'],y=df1['tip'],c=df1['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df1['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.relplot(x=df1['total_bill'],y=df1['tip'],style=df1['smoker'])
# Out:
# c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x=df1['total_bill'],y=df1['tip'],hue=df1['size'])
# Out:
# c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x=df1['total_bill'],y=df1['tip'],style=df1['size'],hue=df1['time'])
# Out:
# c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x=df1['day'],y=df1['total_bill'],hue=df1['size'])
# Out:
# c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x=df1['smoker'],y=df1['tip'])
# Out:
# c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x=df1['total_bill'],y=df1['tip'])

# %%
sns.pairplot(df1,hue='day')
# Out:
# c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df)
# Out:
# c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
