# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen

# %%
search = input('Enter searching key :')
search = search.replace(' ','+')

# %%
flipkart_url = 'https://www.flipkart.com/search?q='+search

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=i+phone+11'

# %%
client = requests.get(flipkart_url)

# %%
flipkart_page = client.text

# %%
print(flipkart_page)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" si
# ...

# %%
flipkart_html = bs(flipkart_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
print(flipkart_html)
# Out:
# <!DOCTYPE html>
# ...

# %%
item_box = flipkart_html.find_all('div',{'class':'_1AtVbE col-12-12'})

# %%
item_box
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=i+phone+11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=t
# ...

# %%
len(item_box)
# Out:
# 30

# %%
product_link = 'https://www.flipkart.com'+item_box[2].div.div.a['href']

# %%
del item_box[:2]

# %%
try:
    for link in item_box:
        print('https://www.flipkart.com'+link.div.div.a['href'])
except Exception as e:
    print('I am handle this type of error ',e)
# Out:
# https://www.flipkart.com/apple-iphone-11-white-64-gb-includes-earpods-power-adapter/p/itm2644c3764fc54?pid=MOBFKCTSHAWGGFHM&lid=LSTMOBFKCTSHAWGGFHMNDVENT&marketplace=FLIPKART&q=i+phone+11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=9b085e00-16ea-4c6e-90ae-2a2c9c5983d7.MOBFKCTSHAWGGFHM.SEARCH&ppt=None&ppn=None&ssid=tzyb2srcbk0000001712831398284&qH=f2b0d47636762520
# https://www.flipkart.com/apple-iphone-11-purple-64-gb/p/itm2b8d03427ddac?pid=MOBFWQ6BTFFJKGKE&lid=LSTMOBFWQ6BTFFJKGKE6U3GXK&marketplace=FLIPKART&q=i+phone+11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=9b085e00-16ea-4c6e-90ae-2a2c9c5983d7.MOBFWQ6BTFFJKGKE.SEARCH&ppt=None&ppn=None&ssid=tzyb2srcbk0000001712831398284&qH=f2b0d47636762520
# ...

# %%
product_link
# Out:
# 'https://www.flipkart.com/apple-iphone-11-red-64-gb/p/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&q=i+phone+11&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=9b085e00-16ea-4c6e-90ae-2a2c9c5983d7.MOBFWQ6BYYV3FCU7.SEARCH&ppt=None&ppn=None&ssid=tzyb2srcbk0000001712831398284&qH=f2b0d47636762520'

# %%
product_link
# Out:
# 'https://www.flipkart.com/apple-iphone-11-red-64-gb/p/itmc3935326f2feb?pid=MOBFWQ6BYYV3FCU7&lid=LSTMOBFWQ6BYYV3FCU7ZCY7Y9&marketplace=FLIPKART&q=i+phone+11&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=9b085e00-16ea-4c6e-90ae-2a2c9c5983d7.MOBFWQ6BYYV3FCU7.SEARCH&ppt=None&ppn=None&ssid=tzyb2srcbk0000001712831398284&qH=f2b0d47636762520'

# %%
product_page = requests.get(product_link)

# %%
product_page = product_page.text

# %%
product_html = bs(product_page,'html.parser')

# %%
print(product_html)
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box = product_html.find_all('div',{'class':'_16PBlm _3_IKGE'})

# %%
comment_box[1].div.div.find
# Out:
# <p class="_2-N8zT">Terrific purchase</p>

# %%
for i in comment_box:
    print(i.div.div.p.text)
# Out:
# Wonderful
# Terrific purchase
# Classy product
# Must buy!
# Terrific
# Just wow!
# Fabulous!

# %%
comment_box[0].find_all('div',{'class':''})[0].text
# Out:
# 'This is amazing at allREAD MORE'

# %%
for i in comment_box:
    print(i.find_all('div',{'class':''})[0].text.encode().decode())
# Out:
# This is amazing at allREAD MORE
# Value for money 😍READ MORE
# Camera is awesomeBest battery backupA performer 👌🏻It will be a real value for money if they provide charger and earphone inbox!READ MORE
# It’s really awesomeREAD MORE
# Very very goodREAD MORE
# Perfect Product!!READ MORE
# Super🔥 and good performance 👌❤️READ MORE

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5
