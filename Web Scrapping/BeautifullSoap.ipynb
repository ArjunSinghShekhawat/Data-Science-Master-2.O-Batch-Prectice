# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
search = input("Enter searching key :")
search = search.replace(" ","")

# %%
flipkart_url = 'https://www.flipkart.com/search?q='+search

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11pro'

# %%
flipkart_page = requests.get(flipkart_url)

# %%
flipkart_page.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" s
# ...

# %%
flipkart_html = bs(flipkart_page.text,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
items_box = flipkart_html.findAll('div',{"class":'_1AtVbE col-12-12'})

# %%
len(items_box)
# Out:
# 27

# %%
product_link = 'https://www.flipkart.com'+items_box[5].div.div.div.a['href']

# %%
product_link
# Out:
# 'https://www.flipkart.com/apple-iphone-11-pro-max-silver-512-gb/p/itmd4aeaf1585645?pid=MOBFKCTSGQWSAKDG&lid=LSTMOBFKCTSGQWSAKDGBKDFSB&marketplace=FLIPKART&q=iphone11pro&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=4024e515-6699-4b6b-b29b-044621c856d0.MOBFKCTSGQWSAKDG.SEARCH&ppt=None&ppn=None&ssid=mppzf676dc0000001712592088177&qH=8c67e3c01d95ccf5'

# %%
del items_box[0:2]

# %%
import logging

logging.basicConfig(filename='scrapper.log',level=logging.DEBUG)

# %%
try:
    for link in items_box:
        print('https://www.flipkart.com'+link.div.div.div.a['href'])
except Exception as e:
    logging.info("I am handle this error {} ".format(e))
# Out:
# https://www.flipkart.com/apple-iphone-11-pro-gold-512-gb/p/itm29ba3b4eeb4d5?pid=MOBFKCTS7CGXBRYE&lid=LSTMOBFKCTS7CGXBRYEVDPFSF&marketplace=FLIPKART&q=iphone11pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=4024e515-6699-4b6b-b29b-044621c856d0.MOBFKCTS7CGXBRYE.SEARCH&ppt=None&ppn=None&ssid=mppzf676dc0000001712592088177&qH=8c67e3c01d95ccf5
# https://www.flipkart.com/apple-iphone-11-pro-space-grey-512-gb/p/itmcd1f0ddbf1c21?pid=MOBFKCTSRTHRQTFT&lid=LSTMOBFKCTSRTHRQTFTSIZYYS&marketplace=FLIPKART&q=iphone11pro&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=4024e515-6699-4b6b-b29b-044621c856d0.MOBFKCTSRTHRQTFT.SEARCH&ppt=None&ppn=None&ssid=mppzf676dc0000001712592088177&qH=8c67e3c01d95ccf5
# ...

# %%
product_link
# Out:
# 'https://www.flipkart.com/apple-iphone-11-pro-max-silver-512-gb/p/itmd4aeaf1585645?pid=MOBFKCTSGQWSAKDG&lid=LSTMOBFKCTSGQWSAKDGBKDFSB&marketplace=FLIPKART&q=iphone11pro&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=4024e515-6699-4b6b-b29b-044621c856d0.MOBFKCTSGQWSAKDG.SEARCH&ppt=None&ppn=None&ssid=mppzf676dc0000001712592088177&qH=8c67e3c01d95ccf5'

# %%
product_req = requests.get(product_link)

# %%
product_req
# Out:
# <Response [200]>

# %%
product_req.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" s
# ...

# %%
product_html = bs(product_req.text,'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
all_comments = product_html.findAll('div',{'class':'_16PBlm'})

# %%
all_comments
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Highly recommended</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Battery - more or less 2 days<br/>Camera - can now perform very good in low light (night )<br/>Heating- no heating for 15+ days<br/>Charging- Quick charger ( which now comes in box ) charges 1-80 in less than an hour. The next 20 requires next 25 mins or so.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201910/blobio-imr-201910_7c04721872244bfabe6b46bad66575b2.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201910/blobio-imr-201910_e2978e5d1f
# ...

# %%
all_comments[0].div.div.div.p.text
# Out:
# 'Highly recommended'

# %%
try:
    for comment in all_comments:
        print(comment.div.div.div.p.text)
except Exception as e:
    logging.info('I am handle this type of error {} '.format(e))
# Out:
# Highly recommended
# Worth every penny
# Good quality product
# Perfect product!
# Worth every penny
# Must buy!
# Terrific purchase
# Must buy!
# Great product
# Mind-blowing purchase

# %%
all_comments[0].div.div.find_all('div',{'class':""})[0].text
# Out:
# 'Battery - more or less 2 daysCamera - can now perform very good in low light (night )Heating- no heating for 15+ daysCharging- Quick charger ( which now comes in box ) charges 1-80 in less than an hour. The next 20 requires next 25 mins or so.READ MORE'

# %%
try:
    for comment in all_comments:
        print(comment.div.div.find_all('div',{'class':""})[0].text)
except Exception as e:
    logging.info("I am handle this type of problem {} ".format(e))
# Out:
# Battery - more or less 2 daysCamera - can now perform very good in low light (night )Heating- no heating for 15+ daysCharging- Quick charger ( which now comes in box ) charges 1-80 in less than an hour. The next 20 requires next 25 mins or so.READ MORE
# Just Awesome, For Night mode in camera no one can beat Iphone, performance super fast, portraits mono mode just ossm, Even in battery backup is now improved than previous iphone,  in the box ,apple gives Fast charger 👌🏻👌🏻👌🏻READ MORE
# impressively Nice......One of the greatest iPhone i ever used ....All was like Never before ...it's just Amazing ...Battery Life is too good ...2 Days with hevy usedCamera also like Apple Quality best everREAD MORE
# ...

# %%
all_comments[0].div.div.div.div.text
# Out:
# '5'

# %%
try:
    for rating in all_comments:
        print(rating.div.div.div.div.text)
except Exception as e:
    logging.info('I am handle this type of problem {} '.format(e))
# Out:
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# 5
# 5

# %%
all_comments[0].div.div.find_all('div',{'class':'_21YjFX _2A07HP'})[0]
# Out:
# <div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201910/blobio-imr-201910_7c04721872244bfabe6b46bad66575b2.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div>
