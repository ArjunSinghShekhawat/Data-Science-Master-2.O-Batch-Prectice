# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import keras

# %%
print('tensorflow version',tf.__version__)
print('Keras version ',tf.keras.__version__)
# Out:
# tensorflow version 2.16.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 print('tensorflow version',tf.__version__)
# ----> 2 print('Keras version ',tf.keras.__version__)
#
# AttributeError: module 'keras._tf_keras.keras' has no attribute '__version__'

# %%
import os

# %%
os.getcwd()
# Out:
# 'e:\\Data Science 2.0 Course Prectice\\deep Learning'

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
tf.config.list_physical_devices('CPU')
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (3.2.1)
# Requirement already satisfied: absl-py in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from keras) (0.11.0)
# Requirement already satisfied: ml-dtypes in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from keras) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from rich->keras) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shekh\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

print('TensorFlow version:', tf.__version__)
print('Keras version:', tf.keras.__version__)
# Out:
# TensorFlow version: 2.16.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       1 import tensorflow as tf
#       3 print('TensorFlow version:', tf.__version__)
# ----> 4 print('Keras version:', tf.keras.__version__)
#
# AttributeError: module 'keras._tf_keras.keras' has no attribute '__version__'

# %%
mnist = tf.keras.datasets.mnist

# %%
mnist
# Out:
# <module 'keras.datasets.mnist' from 'c:\\Users\\shekh\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\keras\\datasets\\mnist\\__init__.py'>

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
x_train[0].shape
# Out:
# (28, 28)

# %%
x_train.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(x_train[2])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(x_train[0],annot=True,cmap='binary')
# Out:
# <Axes: >

# %%
import warnings
warnings.filterwarnings('ignore')
layers = [
    tf.keras.layers.Flatten(input_shape=[28,28],name='InputLayer'),
    tf.keras.layers.Dense(300,activation='relu', name='hiddenlayer1'),
    tf.keras.layers.Dense(100,activation='relu',name='hiddenlayer2'),
    tf.keras.layers.Dense(10,activation='softmax',name='outputLayer')  
]

# %%
model_clf = tf.keras.models.Sequential(layers)

# %%
model_clf
# Out:
# <Sequential name=sequential_1, built=True>

# %%
model_clf.layers
# Out:
# [<Flatten name=InputLayer, built=True>,
#  <Dense name=hiddenlayer1, built=True>,
#  <Dense name=hiddenlayer2, built=True>,
#  <Dense name=outputLayer, built=True>]

# %%
model_clf.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ InputLayer (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hiddenlayer1 (Dense)            │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hiddenlayer2 (Dense)            │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ outputLayer (Dense)             │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 266,610 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)
