# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop("PassengerId",axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("PassengerId",axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = {
    'name':["arjun","manjeet","rahul"],
    'age':[12,43,56],
    'course':['data science','machine learning','deep learning']
}

# %%
d
# Out:
# {'name': ['arjun', 'manjeet', 'rahul'],
#  'age': [12, 43, 56],
#  'course': ['data science', 'machine learning', 'deep learning']}

# %%
pd.DataFrame(d)
# Out:
#       name  age            course
# 0    arjun   12      data science
# 1  manjeet   43  machine learning
# 2    rahul   56     deep learning

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
g = df1.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
#           PassengerId  Pclass  \
# Survived
# 0              245412    1390
# 1              151974     667
#
#                                                        Name  \
# Survived
# 0         Braund, Mr. Owen HarrisAllen, Mr. William Henr...
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalefema...   8219.67    162
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282113803347742237736PP 9...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# ...

# %%
g.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1870, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1869 try:
# -> 1870     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1871 except Exception as err:
#
# File c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\shekh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
g1 = df1.groupby('Pclass')

# %%
g1.sum()
# Out:
#         PassengerId  Survived  \
# Pclass
# 1             99705       136
# 2             82056        87
# 3            215625       119
#
#                                                      Name  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalefemalemalefemalemalemalemalefemalemalema...  7111.42     90
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          77  PC 175991138031746311378311378819950PC 17601PC...  18177.4125
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
a1 = df[['Name','Survived','Pclass']][0:5]

# %%
a2 = df[['Name','Survived','Pclass']][5:10]

# %%
a1
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
a2
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
pd.concat([a1,a2])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
pd.concat([a1,a2],axis=1)
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0     1.0
# 4                           Allen, Mr. William Henry       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# ...

# %%
pd.concat([a1,a2],axis=1).fillna("Arjun")
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0    1.0
# 4                           Allen, Mr. William Henry      0.0    3.0
# 5                                              Arjun    Arjun  Arjun
# 6                                              Arjun    Arjun  Arjun
# 7                                              Arjun    Arjun  Arjun
# 8                                              Arjun    Arjun  Arjun
# 9                                              Arjun    Arjun  Arjun
#
#                                                 Name Survived Pclass
# 0                                              Arjun    Arjun  Arjun
# 1                                              Arjun    Arjun  Arjun
# ...

# %%
a1 = {
    "key1":[1,2,4,5,6],
    "key2":[4,5,6,7,8],
    "key3":[3,4,5,6,6]
}

# %%
a2 = {
    "key1":[1,2,45,6,67],
    "key4":[4,5,6,7,8],
    "key5":[3,4,5,6,6]
}

# %%
q1  = pd.DataFrame(a1)

# %%
q2 = pd.DataFrame(a2)

# %%
pd.merge(q1,q2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3     4     3
# 1     2     5     4     5     4
# 2     6     8     6     7     6

# %%
pd.merge(q1,q2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0   4.0   3.0
# 1     2   5.0   4.0   5.0   4.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %% [markdown]
# q1

# %%
pd.merge(q1,q2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3   4.0   3.0
# 1     2     5     4   5.0   4.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %% [markdown]
# q2

# %%
pd.merge(q1,q2,how='right',on='key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0     4     3
# 1     2   5.0   4.0     5     4
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
q1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
pd.merge(q1,q2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1     4     3
# 1        1     4     3       2     5     4
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1     4     3
# 6        2     5     4       2     5     4
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1     4     3
# 11       4     6     5       2     5     4
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1     4     3
# 16       5     7     6       2     5     4
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1     4     3
# ...

# %%
q2
# Out:
#    key1  key4  key5
# 0     1     4     3
# 1     2     5     4
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
q1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
pd.merge(q1,q2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0   4.0   3.0
# 1     2   5.0   4.0   5.0   4.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
a1 =pd.DataFrame({
    "key1":[1,2,4,5,6],
    "key2":[4,5,6,7,8],
    "key3":[3,4,5,6,6]
},
index=['a','b','c','d','e']
)

a2 =pd.DataFrame({
    "key4":[1,2,45,6,67],
    "key5":[4,5,6,7,8],
    "key6":[3,4,5,6,6]
},
index=['a','b','f','g','h']
)

# %%
a1.join(a2)
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     4     3   1.0   4.0   3.0
# b     2     5     4   2.0   5.0   4.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
a1.join(a2,how='left')
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     4     3   1.0   4.0   3.0
# b     2     5     4   2.0   5.0   4.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
a1.join(a2,how='right')
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   4.0   3.0     1     4     3
# b   2.0   5.0   4.0     2     5     4
# f   NaN   NaN   NaN    45     6     5
# g   NaN   NaN   NaN     6     7     6
# h   NaN   NaN   NaN    67     8     6

# %%
a1.join(a2,how='cross')
# Out:
#     key1  key2  key3  key4  key5  key6
# 0      1     4     3     1     4     3
# 1      1     4     3     2     5     4
# 2      1     4     3    45     6     5
# 3      1     4     3     6     7     6
# 4      1     4     3    67     8     6
# 5      2     5     4     1     4     3
# 6      2     5     4     2     5     4
# 7      2     5     4    45     6     5
# 8      2     5     4     6     7     6
# 9      2     5     4    67     8     6
# 10     4     6     5     1     4     3
# 11     4     6     5     2     5     4
# 12     4     6     5    45     6     5
# 13     4     6     5     6     7     6
# 14     4     6     5    67     8     6
# 15     5     7     6     1     4     3
# 16     5     7     6     2     5     4
# 17     5     7     6    45     6     5
# 18     5     7     6     6     7     6
# 19     5     7     6    67     8     6
# 20     6     8     6     1     4     3
# 21     6     8     6     2     5     4
# 22     6     8     6    45     6     5
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['INR'] = df['Fare'].apply(lambda x:x*80)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       INR
# 0      0         A/5 21171   7.2500   NaN        S   580.000
# 1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# 3      0            113803  53.1000  C123        S  4248.000
# ...

# %%
df['name_length'] = df['Name'].apply(lambda name:len(name))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       INR  name_length
# 0      0         A/5 21171   7.2500   NaN        S   580.000           23
# 1      0          PC 17599  71.2833   C85        C  5702.664           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000           22
# ...

# %%
def categoty_define(x):
    if x<10:
        return "Chipest"
    elif x>10 and x<20:
        return 'Midest'
    else:
        return "Hieghts"
df['category'] = df['Fare'].apply(categoty_define)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       INR  name_length  \
# 0      0         A/5 21171   7.2500   NaN        S   580.000           23
# 1      0          PC 17599  71.2833   C85        C  5702.664           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000           22
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked     INR  \
# 886    male  27.0      0      0      211536  13.00   NaN        S  1040.0
# 887  female  19.0      0      0      112053  30.00   B42        S  2400.0
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S  1876.0
# 889    male  26.0      0      0      111369  30.00  C148        C  2400.0
# 890    male  32.0      0      0      370376   7.75   NaN        Q   620.0
#
#      name_length category
# 886           21   Midest
# ...
