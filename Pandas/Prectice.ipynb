# %%
import pandas as pd

# %%
df = pd.read_csv('E:\Pandas\services (2).csv')

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
df.tail(1)
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 22  23           22         NaN               NaN            NaN
#
#                   application_process  \
# 22  Walk in or apply by phone or mail
#
#                                              audience  \
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility email  ...  \
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...         NaN   NaN  ...
#
#    interpretation_services                                    keywords  \
# 22                     NaN  Ruby on Rails/Postgres/Redis, testing, wic
#
#    languages                  name required_documents  \
# 22       NaN  Example Service Name                NaN
#
#                        service_areas  status           wait_time  \
# 22  San Mateo County, Alameda County  active  No wait to 2 weeks
#
#                    website taxonomy_ids
# 22  http://www.example.com          NaN
#
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df['program_id']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# Name: program_id, dtype: float64

# %%
type(df['program_id'])
# Out:
# pandas.core.series.Series

# %%
df['interpretation_services']
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
list(df['interpretation_services'])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'We offer 3-way interpretation services over the phone via Propio Language Services (http://propio-ls.com).',
#  nan]

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df[['email', 'fees', 'funding_sources']]
# Out:
#                     email                                               fees  \
# 0                     NaN  $2.50 suggested donation for lunch for age 60 ...
# 1                     NaN  None. Donations requested of clients who can a...
# 2                     NaN                                              None.
# 3                     NaN  Vary according to income ($5-$90). Cash, check...
# 4                     NaN      $60 application fee. Cash or checks accepted.
# 5                     NaN  $55 per year membership dues. Classes have fee...
# 6                     NaN  $85 per day. Vary according to income for thos...
# 7                     NaN  Suggested donation of $4.25 per meal for senio...
# 8                     NaN                                              None.
# 9                     NaN                                              None.
# 10                    NaN                                              None.
# ...

# %%
type(df[['email', 'fees', 'funding_sources']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail(2)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...         NaN
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...         NaN
#
#                     email  ...  \
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 21  We offer 3-way interpretation services over th...
# ...

# %%
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df1[['Name', 'Sex', 'Age']]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
df1.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df1[1:3][0:3][['PassengerId','Survived']]
# Out:
#    PassengerId  Survived
# 1            2         1
# 2            3         1

# %%
df2 = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2022.html')

# %%
df2
# Out:
# [     Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
#  0           Miami Heat*  53  29  0.646     —  110.0  105.6  4.23
#  1       Boston Celtics*  51  31  0.622   2.0  111.8  104.5  7.02
#  2      Milwaukee Bucks*  51  31  0.622   2.0  115.5  112.1  3.22
#  3   Philadelphia 76ers*  51  31  0.622   2.0  109.9  107.3  2.57
#  4      Toronto Raptors*  48  34  0.585   5.0  109.4  107.1  2.38
#  5        Chicago Bulls*  46  36  0.561   7.0  111.6  112.0 -0.38
#  6        Brooklyn Nets*  44  38  0.537   9.0  112.9  112.1  0.82
#  7   Cleveland Cavaliers  44  38  0.537   9.0  107.8  105.7  2.04
#  8        Atlanta Hawks*  43  39  0.524  10.0  113.9  112.4  1.55
#  9     Charlotte Hornets  43  39  0.524  10.0  115.3  114.9  0.53
#  10      New York Knicks  37  45  0.451  16.0  106.5  106.6 -0.01
#  11   Washington Wizards  35  47  0.427  18.0  108.6  112.0 -3.23
#  12       Indiana Pacers  25  57  0.305  28.0  111.5  114.9 -3.26
# ...

# %%
a = df2[0]

# %%
len(df)
# Out:
# 23

# %%
a
# Out:
#      Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0           Miami Heat*  53  29  0.646     —  110.0  105.6  4.23
# 1       Boston Celtics*  51  31  0.622   2.0  111.8  104.5  7.02
# 2      Milwaukee Bucks*  51  31  0.622   2.0  115.5  112.1  3.22
# 3   Philadelphia 76ers*  51  31  0.622   2.0  109.9  107.3  2.57
# 4      Toronto Raptors*  48  34  0.585   5.0  109.4  107.1  2.38
# 5        Chicago Bulls*  46  36  0.561   7.0  111.6  112.0 -0.38
# 6        Brooklyn Nets*  44  38  0.537   9.0  112.9  112.1  0.82
# 7   Cleveland Cavaliers  44  38  0.537   9.0  107.8  105.7  2.04
# 8        Atlanta Hawks*  43  39  0.524  10.0  113.9  112.4  1.55
# 9     Charlotte Hornets  43  39  0.524  10.0  115.3  114.9  0.53
# 10      New York Knicks  37  45  0.451  16.0  106.5  106.6 -0.01
# 11   Washington Wizards  35  47  0.427  18.0  108.6  112.0 -3.23
# 12       Indiana Pacers  25  57  0.305  28.0  111.5  114.9 -3.26
# ...

# %%
a.head()
# Out:
#     Eastern Conference   W   L   W/L%   GB   PS/G   PA/G   SRS
# 0          Miami Heat*  53  29  0.646    —  110.0  105.6  4.23
# 1      Boston Celtics*  51  31  0.622  2.0  111.8  104.5  7.02
# 2     Milwaukee Bucks*  51  31  0.622  2.0  115.5  112.1  3.22
# 3  Philadelphia 76ers*  51  31  0.622  2.0  109.9  107.3  2.57
# 4     Toronto Raptors*  48  34  0.585  5.0  109.4  107.1  2.38

# %%
a.to_csv("Players.csv",index=False)

# %%
a1 = pd.read_excel('E:\Pandas\LUSID Excel - Setting up your market data (1).xlsx')

# %%
a1.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
a1.tail()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 23         NaN         NaN         NaN        NaN
# 24         NaN         NaN         NaN        NaN
# 25         NaN         NaN         NaN        NaN
# 26         NaN         NaN         NaN        NaN
# 27         NaN         NaN         NaN        NaN
#
#                                           Unnamed: 4  \
# 23  Although the date can still appears without time
# 24                                               NaN
# 25                      Add an hour to your datetime
# 26                                               NaN
# 27              Subtract a minute from your datetime
#
#                     Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 23  2019-04-10 13:30:45.550000         NaN        NaN        NaN        NaN
# 24                         NaN         NaN        NaN        NaN        NaN
# 25  2019-04-10 14:30:45.550000         NaN        NaN        NaN        NaN
# ...

# %%
a1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
a1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[df['Fare']>32.204208][['Name','Fare']]
# Out:
#                                                   Name      Fare
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   71.2833
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   53.1000
# 6                              McCarthy, Mr. Timothy J   51.8625
# 23                        Sloper, Mr. William Thompson   35.5000
# 27                      Fortune, Mr. Charles Alexander  263.0000
# ..                                                 ...       ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  164.8667
# 863                  Sage, Miss. Dorothy Edith "Dolly"   69.5500
# 867               Roebling, Mr. Washington Augustus II   50.4958
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)   52.5542
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)   83.1583
#
# [211 rows x 2 columns]

# %%
df[(df['Age']<20) & (df['Fare']>32.204208) & (df['Pclass']==1) & (df['Survived']==1) & (df['Embarked']=='S') &(df['Sex']=='male')][['Name','Cabin']]
# Out:
#                                     Name    Cabin
# 305       Allison, Master. Hudson Trevor  C22 C26
# 445            Dodge, Master. Washington      A34
# 802  Carter, Master. William Thornton II  B96 B98

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0:5,[1,3]]
# Out:
#    Survived                                               Name
# 0         0                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1                             Heikkinen, Miss. Laina
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0                           Allen, Mr. William Henry

# %%
df.loc[0:5,['Name','Survived']]
# Out:
#                                                 Name  Survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                           Allen, Mr. William Henry         0
# 5                                   Moran, Mr. James         0

# %%
pd.Categorical(df['Ticket'])
# Out:
# ['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450', ..., '211536', '112053', 'W./C. 6607', '111369', '370376']
# Length: 891
# Categories (681, object): ['110152', '110413', '110465', '110564', ..., 'W./C. 6609', 'W.E.P. 5734', 'W/C 14208', 'WE/P 5735']

# %%
pd.unique(df['Ticket'])
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
a1 = df[0:10][['Name','Pclass','Sex']]

# %%
a1
# Out:
#                                                 Name  Pclass     Sex
# 0                            Braund, Mr. Owen Harris       3    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female
# 2                             Heikkinen, Miss. Laina       3  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female
# 4                           Allen, Mr. William Henry       3    male
# 5                                   Moran, Mr. James       3    male
# 6                            McCarthy, Mr. Timothy J       1    male
# 7                     Palsson, Master. Gosta Leonard       3    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)       2  female

# %%
a1 = df[0:11]['Name']

# %%
a1
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
a1 = df['Name']

# %%
a1
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(a1)
# Out:
# pandas.core.series.Series

# %%
a1 = pd.DataFrame({"Name":['Arjun','rahul','mukesh','suresh','kesav','yadav','manish']})

# %%
a1
# Out:
#      Name
# 0   Arjun
# 1   rahul
# 2  mukesh
# 3  suresh
# 4   kesav
# 5   yadav
# 6  manish

# %%
list(a1)
# Out:
# ['Name']

# %%
a1 = pd.Series(['Arjun','rahul','mukesh','suresh','kesav','yadav','manish'],index=['a','b','c','d','e','f','g'])

# %%
a1
# Out:
# a     Arjun
# b     rahul
# c    mukesh
# d    suresh
# e     kesav
# f     yadav
# g    manish
# dtype: object

# %%
a1['b']
# Out:
# 'rahul'

# %%
a1[2]
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_1552\3065876008.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   a1[2]
# 'mukesh'

# %%
a1['g']
# Out:
# 'manish'

# %%
a1[4]
# Out:
# C:\Users\shekh\AppData\Local\Temp\ipykernel_1552\845470129.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   a1[4]
# 'kesav'

# %%
s1 = pd.Series([1,2,3,4,5])

# %%
s2 = pd.Series([6,7,8,9,10],index=['a','b','c','d','e'])

# %%
s1+s2
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %%
s1-s2
# Out:
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64

# %%
s1*s2
# Out:
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64

# %%
s1+s2
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64

# %%
s1*s2
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['INR'] = df['Fare'].apply(lambda x:x*80)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['New_col'] = df['Survived']+df['Pclass']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# INR              0
# New_col          0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# INR              0
# New_col          0
# dtype: int64

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Cabin'].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %%
df.isnull().sum()
# Out:
# index            0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# INR              0
# New_col          0
# dtype: int64

# %%
df.set_index("Name",inplace=True)

# %%
df
# Out:
#                                                     index  PassengerId  \
# Name
# Braund, Mr. Owen Harris                                 0            1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1            2
# Heikkinen, Miss. Laina                                  2            3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            3            4
# Allen, Mr. William Henry                                4            5
# ...                                                   ...          ...
# Montvila, Rev. Juozas                                 886          887
# Graham, Miss. Margaret Edith                          887          888
# Johnston, Miss. Catherine Helen "Carrie"              888          889
# Behr, Mr. Karl Howell                                 889          890
# Dooley, Mr. Patrick                                   890          891
#
#                                                     Survived  Pclass     Sex  \
# Name
# ...

# %%
df
# Out:
#                                                     index  PassengerId  \
# Name
# Braund, Mr. Owen Harris                                 0            1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1            2
# Heikkinen, Miss. Laina                                  2            3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            3            4
# Allen, Mr. William Henry                                4            5
# ...                                                   ...          ...
# Montvila, Rev. Juozas                                 886          887
# Graham, Miss. Margaret Edith                          887          888
# Johnston, Miss. Catherine Helen "Carrie"              888          889
# Behr, Mr. Karl Howell                                 889          890
# Dooley, Mr. Patrick                                   890          891
#
#                                                     Survived  Pclass     Sex  \
# Name
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  index  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      1            2
# 2                               Heikkinen, Miss. Laina      2            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      3            4
# 4                             Allen, Mr. William Henry      4            5
# ..                                                 ...    ...          ...
# 886                              Montvila, Rev. Juozas    886          887
# 887                       Graham, Miss. Margaret Edith    887          888
# 888           Johnston, Miss. Catherine Helen "Carrie"    888          889
# 889                              Behr, Mr. Karl Howell    889          890
# 890                                Dooley, Mr. Patrick    890          891
#
# ...

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.groupby('Pclass')['Fare'].max()
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
df.groupby('Fare')['Ticket'].max()
# Out:
# Fare
# 0.0000          LINE
# 4.0125          2648
# 5.0000           695
# 6.2375        345364
# 6.4375          2683
#               ...
# 227.5250    PC 17757
# 247.5208    PC 17558
# 262.3750    PC 17608
# 263.0000       19950
# 512.3292    PC 17755
# Name: Ticket, Length: 248, dtype: object

# %%
a1 = pd.DataFrame({"key1":[1,4,2,6,7],"key2":[6,4,8,9,3],'key3':[2,4,2,7,6]},index=[1,2,3,4,5])
a2 = pd.DataFrame({"key1":[1,5,3,6,1],"key4":[6,4,8,9,3],'key5':[2,4,2,7,6]},index=[11,2,3,12,15])

# %%
a1
# Out:
#    key1  key2  key3
# 1     1     6     2
# 2     4     4     4
# 3     2     8     2
# 4     6     9     7
# 5     7     3     6

# %%
a2
# Out:
#     key1  key4  key5
# 11     1     6     2
# 2      5     4     4
# 3      3     8     2
# 12     6     9     7
# 15     1     3     6

# %%
pd.merge(a1,a2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     2     6     2
# 1     1     6     2     3     6
# 2     6     9     7     9     7

# %%
pd.merge(a1,a2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     2   6.0   2.0
# 1     1     6     2   3.0   6.0
# 2     4     4     4   NaN   NaN
# 3     2     8     2   NaN   NaN
# 4     6     9     7   9.0   7.0
# 5     7     3     6   NaN   NaN

# %%
pd.merge(a1,a2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   6.0   2.0     6     2
# 1     5   NaN   NaN     4     4
# 2     3   NaN   NaN     8     2
# 3     6   9.0   7.0     9     7
# 4     1   6.0   2.0     3     6

# %%
pd.concat([a1,a2],axis=1)
# Out:
#     key1  key2  key3  key1  key4  key5
# 1    1.0   6.0   2.0   NaN   NaN   NaN
# 2    4.0   4.0   4.0   5.0   4.0   4.0
# 3    2.0   8.0   2.0   3.0   8.0   2.0
# 4    6.0   9.0   7.0   NaN   NaN   NaN
# 5    7.0   3.0   6.0   NaN   NaN   NaN
# 11   NaN   NaN   NaN   1.0   6.0   2.0
# 12   NaN   NaN   NaN   6.0   9.0   7.0
# 15   NaN   NaN   NaN   1.0   3.0   6.0

# %%
pd.date_range(start='1-01-2000',end='1-02-2000')
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02'], dtype='datetime64[ns]', freq='D')

# %%
pd.Timedelta(start='01-01-2001',end='01-02-2002')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 pd.Timedelta(start='01-01-2001',end='01-02-2002')
#
# File timedeltas.pyx:1761, in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# File timedeltas.pyx:940, in pandas._libs.tslibs.timedeltas._to_py_int_float()
#
# TypeError: Invalid type <class 'str'>. Must be int or float.
